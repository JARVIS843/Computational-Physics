# %%
from math import*
import numpy as np
import matplotlib.pyplot as plt

# %%
interval = np.linspace(-4,4,1000)
def Func(x):
    result= e**(-(x)**2)*np.sin(3*pi*x)
    return result

y = Func(interval)
plt.plot(interval,y)
